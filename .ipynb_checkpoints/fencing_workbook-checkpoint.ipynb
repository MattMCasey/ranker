# %%
from pymongo import MongoClient
import requests
import time
from bs4 import BeautifulSoup
import numpy as np
import datetime as dt
import pandas as pd
import boardgamegeek as bgg
import math
from datetime import datetime
import time
from collections import Counter, defaultdict

# %%
client = MongoClient()
db = client['fencing']

# %%
page = '''https://askfred.net/Results/search.php?
ops%5Bfirst_name%5D=first_name&vals%5Bfirst_name%5D=&ops%
5Blast_name%5D=last_name&vals%5Blast_name%5D=&f%5Bweapon%5D=&ops%
5Bdate_1%5D=date_1_eq&vals%5Bdate_1%5D=&ops%5Bdate_2%
5D=date_2_eq&vals%5Bdate_2%5D=&f%5Bclub_id%5D=4160&f%
5Bcompetitor_division_id%5D=&ops%5Bplace%5D=place_eq&vals%
5Bplace%5D=&f%5Bevent_gender%5D=&f%5Bage_limit%5D=&f%
5Bevent_rating_limit%5D=&ops%5Bevent_rating%5D=event_rating_eq&vals%
5Bevent_rating%5D=&f%5Bis_team%5D=&ops%5Brating_earned%
5D=eq&vals%5Brating_earned_letter%5D=&vals%5Brating_earned_year%
5D=&f%5Btournament_name_contains%5D=&search_submit=
Search&page_id=2&page_id=3&page_id=4&page_id=3&page_id=2&page_id=1'''

# %%
test = requests.get(page)

# %%
test = requests.get(page)
souped = BeautifulSoup(test.content, 'html.parser')
evens = souped.select('tr.evenrow')
odds = souped.select('tr.oddrow')
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.

# %%
for i in range(len(str(evens[0]).split('<'))):
    print(i , " : " , str(evens[0]).split('<')[i])
# Out:
# 0  :
# 1  :  tr class="evenrow">
#
# 2  :  td nowrap="">10/01/2017
# 3  :  /td>
#
# 4  :  td>
# 5  :  a href="https://askfred.net/Results/index.php?tournament_id=38070&amp;FREDSID=a2q8qdnon37uvnijqt5p6afgd6">Five Weapon E Meet
# 6  :  /a>
# 7  :  /td>
#
# 8  :  td align="right" nowrap="">EUnder Senior Mixed Foil
# 9  :  /td>
#
# 10  :  td align="center" nowrap="">D1
# 11  :  /td>
#
# 12  :  td align="right" nowrap="">1st of 17
# 13  :  /td>
#
# 14  :  td>
# 15  :  div>Sullivan, Jackson
# 16  :  /div>
# 17  :  /td>
#
# 18  :  td nowrap="">
#
# 19  :  div class="div_club">
# 20  :  a href="#" onclick="return false;">MOE
# 21  :  /a>
# 22  :  /div>
#
# 23  :  div class="div_club" style="display:none">
# 24  :  a href="#" onclick="return false;">Moe Fencing Club
# 25  :  /a>
# 26  :  /div>
#
# 27  :  /td>
#
# 28  :  td nowrap="">D2017
# 29  :  /td>
#
# 30  :  /tr>

# %% [markdown]
# when split on '<':
#
# 2 = date
# 5 = URL / event name
# 8 = event
# 10 = event rating
# 12 = finish and competitors
# 15 = name
# 20 = club

# %%
date = str(evens[0]).split('<')[2][-10:]

# %%
url_tourney = str(evens[0]).split('<')[5]#.index('"')

url = url_tourney[8:]
url_end = url.index('"')
url = url[:url_end]

event_start = url_tourney.index('>')+1
event = url_tourney[event_start:]

# %%
event = str(evens[0]).split('<')[8][27:]

# %%
event_rating = str(evens[0]).split('<')[10][-2:]

# %%
place_size = str(evens[0]).split('<')[12]
ps_start = place_size.index('>')+1
ps_splits = place_size[ps_start:].split(' ')
size = ps_splits[2]
place = ps_splits[0][:-2]

# %%
name = str(evens[0]).split('<')[15][4:]

# %%
club = str(evens[0]).split('<')[20]
club_start = club.index('>') + 1
club = club[club_start:]
club
# Out:
# 'MOE'

# %%
def extract_details(line):
    line = str(line).split('<')
    
    date = line[2][-10:]
    date = datetime.strptime(date, '%m/%d/%Y')
    event = line[8][27:]
    event_rating = line[10][-2:]
    name = line[15][4:]
    
    
    url_tourney = line[5] #gets line containing url and tournament name
    url = url_tourney[8:]
    url_end = url.index('"')
    event_start = url_tourney.index('>')+1 #prepping line for extract
    
    url = url[:url_end] #extracting url and event
    tourney = url_tourney[event_start:]
    
    
    place_size = line[12] #gets line w/place & size
    
    ps_start = place_size.index('>')+1 #prepping line for extract
    ps_splits = place_size[ps_start:].split(' ')
    
    size = ps_splits[2] #extracting
    place = ps_splits[0][:-2]
    
    
    club = str(evens[0]).split('<')[20]
    club_start = club.index('>') + 1
    club = club[club_start:]
    
    
    return date, tourney, event_rating, name, event, place, size, club, url

# %%
def scrape_page(num, club_id):
    
    page = '''https://askfred.net/Results/search.php?
    ops%5Bfirst_name%5D=first_name&vals%5Bfirst_name%5D=&ops%
    5Blast_name%5D=last_name&vals%5Blast_name%5D=&f%5Bweapon%5D=&ops%
    5Bdate_1%5D=date_1_eq&vals%5Bdate_1%5D=&ops%5Bdate_2%
    5D=date_2_eq&vals%5Bdate_2%5D=&f%5Bclub_id%5D='''+str(club_id)+'''&f%
    5Bcompetitor_division_id%5D=&ops%5Bplace%5D=place_eq&vals%
    5Bplace%5D=&f%5Bevent_gender%5D=&f%5Bage_limit%5D=&f%
    5Bevent_rating_limit%5D=&ops%5Bevent_rating%5D=event_rating_eq&vals%
    5Bevent_rating%5D=&f%5Bis_team%5D=&ops%5Brating_earned%
    5D=eq&vals%5Brating_earned_letter%5D=&vals%5Brating_earned_year%
    5D=&f%5Btournament_name_contains%5D=&search_submit=
    Search&page_id=2&page_id=3&page_id=4&page_id=3&page_id=2&page_id='''+str(num)
    
    raw = requests.get(page)
    souped = BeautifulSoup(raw.content, 'html.parser')
    evens = souped.select('tr.evenrow')
    odds = souped.select('tr.oddrow')
    
    return evens, odds

# %%
extract_details(odds[5])
# Out:
# (datetime.datetime(2017, 9, 29, 0, 0),
#  'Moe Found Friday Foil Open #114',
#  'NR',
#  'Tsai, Philip',
#  'Mixed Foil',
#  '8',
#  '22',
#  'MOE',
#  'https://askfred.net/Results/index.php?tournament_id=38657&amp;FREDSID=a2q8qdnon37uvnijqt5p6afgd6')

# %%
def award_points(place, size):
    place = int(place)
    size = int(size)
    
    bonus_max = int(math.log(size, 2)) + 1
    
    if math.log(place, 2) == int(math.log(place, 2)):
        bracket = int(math.log(place , 2))
    else:
        bracket = int(math.log(place , 2)) + 1
    
    bonus = (bonus_max - bracket)*2
    if bonus < 0:
        bonus = 0
    base = size-place + 1
    
    return bonus, base

# %%
def search_page_grab(url):
    raw = requests.get(url)
    souped = BeautifulSoup(raw.content, 'html.parser')
    evens = souped.select('tr.evenrow')
    odds = souped.select('tr.oddrow')
    return evens, odds

# %%
for entry in odds:
    date, tourney, event_rating, name, event, place, size, club = extract_details(entry)
    print(name)
    print(event)
    print(date)
    print(tourney)
    print(place, 'out of', size)
    #print('place', place)
    bonus, base = award_points(place, size)
    print('bonus', bonus)
    print('base', base)
    print('total', base+bonus)
    print()
# Out:
# Baldini, Andrea
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 1 out of 26
# bonus 10
# base 26
# total 36
#
# Karamete, Irem
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 3 out of 26
# bonus 6
# base 24
# total 30
#
# LaRosee, Matthew
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 5 out of 26
# bonus 4
# base 22
# total 26
#
# Banks, Alex
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 8 out of 26
# bonus 4
# base 19
# total 23
#
# Wilbert, Matthew
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 10 out of 26
# bonus 2
# base 17
# total 19
#
# Wilbert, Gwendolyn
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 15 out of 26
# bonus 2
# base 12
# total 14
#
# Miall, Steven
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 17 out of 26
# bonus 0
# base 10
# total 10
#
# Jenkins, Hannah
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 21 out of 26
# bonus 0
# base 6
# total 6
#
# Kang, Daniel
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 23 out of 26
# bonus 0
# base 4
# total 4
#
# Gardiner, Luke
# Senior Mixed Foil
# 08/25/2017
# Moe Future Scholarship Foil Open
# 25 out of 26
# bonus 0
# base 2
# total 2

# %%
url = 'https://askfred.net/Results/search.php?ops%5Bfirst_name%5D=first_name&vals%5Bfirst_name%5D=Elishua&ops%5Blast_name%5D=last_name&vals%5Blast_name%5D=Litle&f%5Bweapon%5D=&ops%5Bdate_1%5D=date_1_eq&vals%5Bdate_1%5D=&ops%5Bdate_2%5D=date_2_eq&vals%5Bdate_2%5D=&f%5Bclub_id%5D=&f%5Bcompetitor_division_id%5D=&ops%5Bplace%5D=place_eq&vals%5Bplace%5D=&f%5Bevent_gender%5D=&f%5Bage_limit%5D=&f%5Bevent_rating_limit%5D=&ops%5Bevent_rating%5D=event_rating_eq&vals%5Bevent_rating%5D=&f%5Bis_team%5D=&ops%5Brating_earned%5D=eq&vals%5Brating_earned_letter%5D=&vals%5Brating_earned_year%5D=&f%5Btournament_name_contains%5D=&FREDSID=sdbc2mfrb15po1162jttctuc67&search_submit=Search'

# %%
evens, odds = search_page_grab(url)
evens
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# [<tr class="evenrow">
#  <td nowrap="">08/25/2017</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=37182&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">Moe Future Scholarship Foil Open</a></td>
#  <td align="right" nowrap="">Senior Mixed Foil</td>
#  <td align="center" nowrap="">NR</td>
#  <td align="right" nowrap="">3rd of 26</td>
#  <td><div>Litle, Elishua</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">MOE</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Moe Fencing Club</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>, <tr class="evenrow">
#  <td nowrap="">06/17/2017</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=36447&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">NEUSFA 2017 Pomme De Terre - TEAM EVENTS</a></td>
#  <td align="right" nowrap="">Senior Men's Team Foil</td>
#  <td align="center" nowrap=""></td>
#  <td align="right" nowrap="">1st of 8</td>
#  <td><div>Moe 1</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">MOE</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Moe Fencing Club</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>, <tr class="evenrow">
#  <td nowrap="">04/14/2017</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=36458&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">Moe Found Friday Foil Open #105</a></td>
#  <td align="right" nowrap="">Mixed Foil</td>
#  <td align="center" nowrap="">NR</td>
#  <td align="right" nowrap="">3rd of 34</td>
#  <td><div>Litle, Elishua</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">UNAT</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Unattached (or Unknown)</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>, <tr class="evenrow">
#  <td nowrap="">02/03/2017</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=36246&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">Moe Found Friday Foil Open #102</a></td>
#  <td align="right" nowrap="">Mixed Foil</td>
#  <td align="center" nowrap="">NR</td>
#  <td align="right" nowrap="">2nd of 19</td>
#  <td><div>Litle, Elishua</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">MOE</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Moe Fencing Club</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>, <tr class="evenrow">
#  <td nowrap="">09/16/2016</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=34880&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">Moe Found Friday Foil Open #99</a></td>
#  <td align="right" nowrap="">Mixed Foil</td>
#  <td align="center" nowrap="">NR</td>
#  <td align="right" nowrap="">5th of 24</td>
#  <td><div>Litle, Elishua</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">MOE</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Moe Fencing Club</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>, <tr class="evenrow">
#  <td nowrap="">02/26/2016</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=32927&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">Moe Found Friday Foil Open #90</a></td>
#  <td align="right" nowrap="">Mixed Foil</td>
#  <td align="center" nowrap="">NR</td>
#  <td align="right" nowrap="">1st of 18</td>
#  <td><div>Litle, Elishua</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">MOE</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Moe Fencing Club</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>, <tr class="evenrow">
#  <td nowrap="">12/04/2015</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=32144&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">Moe Found Friday Foil Open #85</a></td>
#  <td align="right" nowrap="">Mixed Foil</td>
#  <td align="center" nowrap="">NR</td>
#  <td align="right" nowrap="">3rd of 20</td>
#  <td><div>Litle, Elishua</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">MOE</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Moe Fencing Club</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>, <tr class="evenrow">
#  <td nowrap="">09/12/2015</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=30121&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">Thrust Fall ROC- Div 1A/Div 2 (Region 3)</a></td>
#  <td align="right" nowrap="">Div1A Senior Men's Foil</td>
#  <td align="center" nowrap="">A3</td>
#  <td align="right" nowrap="">6th of 95</td>
#  <td><div>Litle, Elishua</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">MOE</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Moe Fencing Club</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>, <tr class="evenrow">
#  <td nowrap="">08/28/2015</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=30824&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">Moe Found Friday Foil Open #81</a></td>
#  <td align="right" nowrap="">Mixed Foil</td>
#  <td align="center" nowrap="">NR</td>
#  <td align="right" nowrap="">3rd of 30</td>
#  <td><div>Litle, Elishua</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">MOE</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Moe Fencing Club</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>, <tr class="evenrow">
#  <td nowrap="">06/12/2015</td>
#  <td><a href="https://askfred.net/Results/index.php?tournament_id=30148&amp;FREDSID=dck42ocerunfcgmaeeg9oip1c5">Moe Found Friday Foil Open #80</a></td>
#  <td align="right" nowrap="">Mixed Foil</td>
#  <td align="center" nowrap="">NR</td>
#  <td align="right" nowrap="">3rd of 20</td>
#  <td><div>Litle, Elishua</div></td>
#  <td nowrap="">
#  <div class="div_club"><a href="#" onclick="return false;">MOE</a></div>
#  <div class="div_club" style="display:none"><a href="#" onclick="return false;">Moe Fencing Club</a></div>
#  </td>
#  <td nowrap=""></td>
#  </tr>]

# %%
def dict_builder(url, results_dict):
    evens, odds = search_page_grab(url)
    full = evens + odds
    
    for entry in full:
        date, tourney, event_rating, name, event, place, size, club = extract_details(entry)
        bonus, base = award_points(place, size)
        
        event_dict = {
            'tournament': tourney,
            'event': event,
            'rating': event_rating, 
            'place': place,
            'size':size,
            'bonus':bonus,
            'base': base,
            'total': bonus+base}

        if name not in results_dict.keys():
            results_dict[name] = {}
            results_dict[name]['foil'] = {}
            results_dict[name]['saber'] = {}
            results_dict[name]['epee'] = {}
        if 'Foil' in event:
            weapon = 'foil'
        elif 'Epee' in event:
            weapon = 'epee'
        else:
            weapon = 'saber'
        results_dict[name][weapon][date] = event_dict

# %%
results_dict = {}
page = '''https://askfred.net/Results/search.php?
ops%5Bfirst_name%5D=first_name&vals%5Bfirst_name%5D=&ops%
5Blast_name%5D=last_name&vals%5Blast_name%5D=&f%5Bweapon%5D=&ops%
5Bdate_1%5D=date_1_eq&vals%5Bdate_1%5D=&ops%5Bdate_2%
5D=date_2_eq&vals%5Bdate_2%5D=&f%5Bclub_id%5D=4160&f%
5Bcompetitor_division_id%5D=&ops%5Bplace%5D=place_eq&vals%
5Bplace%5D=&f%5Bevent_gender%5D=&f%5Bage_limit%5D=&f%
5Bevent_rating_limit%5D=&ops%5Bevent_rating%5D=event_rating_eq&vals%
5Bevent_rating%5D=&f%5Bis_team%5D=&ops%5Brating_earned%
5D=eq&vals%5Brating_earned_letter%5D=&vals%5Brating_earned_year%
5D=&f%5Btournament_name_contains%5D=&search_submit=
Search&page_id=2&page_id=3&page_id=4&page_id=3&page_id=2&page_id='''
for i in range(5):
    dict_builder(page + str(i), results_dict)
    print(i)
    time.sleep(3)
# Out:
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 0
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 1
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 2
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 3
# Some characters could not be decoded, and were replaced with REPLACEMENT CHARACTER.
# 4

# %%
results_dict = {}
for entry in evens_odds:
    date, tourney, event_rating, name, event, place, size, club = extract_details(entry)
    bonus, base = award_points(place, size)
    event_dict = {
        'tournament': tourney,
        'rating': event_rating, 
        'event': event,
        'place': place, 
        'size':size,
        'bonus':bonus,
        'base': base,
        'total': bonus+base}
    
    if name not in results_dict.keys():
        results_dict[name] = {}
    results_dict[name][date] = event_dict

results_dict
# Out:
# {'Litle, Elishua': {'01/15/2016': {'base': 13,
#    'bonus': 8,
#    'event': 'Mixed Foil',
#    'place': '1',
#    'rating': 'NR',
#    'size': '13',
#    'total': 21,
#    'tournament': 'Moe Found Friday Foil Open #87'},
#   '02/03/2017': {'base': 18,
#    'bonus': 8,
#    'event': 'Mixed Foil',
#    'place': '2',
#    'rating': 'NR',
#    'size': '19',
#    'total': 26,
#    'tournament': 'Moe Found Friday Foil Open #102'},
#   '02/26/2016': {'base': 18,
#    'bonus': 10,
#    'event': 'Mixed Foil',
#    'place': '1',
#    'rating': 'NR',
#    'size': '18',
#    'total': 28,
#    'tournament': 'Moe Found Friday Foil Open #90'},
#   '03/11/2016': {'base': 17,
#    'bonus': 10,
#    'event': 'Mixed Foil',
#    'place': '1',
#    'rating': 'NR',
#    'size': '17',
#    'total': 27,
#    'tournament': 'Moe Found Friday Foil Open #91'},
#   '03/17/2017': {'base': 77,
#    'bonus': 8,
#    'event': "Div1A Senior Men's Foil",
#    'place': '6',
#    'rating': 'A3',
#    'size': '82',
#    'total': 85,
#    'tournament': 'Boston Fencing Club D1A/D2/Bill Hall Vet ROC'},
#   '04/14/2017': {'base': 32,
#    'bonus': 8,
#    'event': 'Mixed Foil',
#    'place': '3',
#    'rating': 'NR',
#    'size': '34',
#    'total': 40,
#    'tournament': 'Moe Found Friday Foil Open #105'},
#   '06/05/2015': {'base': 15,
#    'bonus': 8,
#    'event': 'Mixed Foil',
#    'place': '2',
#    'rating': 'NR',
#    'size': '16',
#    'total': 23,
#    'tournament': 'Moe Found Friday Foil Open #79'},
#   '06/09/2017': {'base': 21,
#    'bonus': 6,
#    'event': 'Mixed Foil',
#    'place': '3',
#    'rating': 'NR',
#    'size': '23',
#    'total': 27,
#    'tournament': 'Moe Found Friday Foil Open #108'},
#   '06/12/2015': {'base': 18,
#    'bonus': 6,
#    'event': 'Mixed Foil',
#    'place': '3',
#    'rating': 'NR',
#    'size': '20',
#    'total': 24,
#    'tournament': 'Moe Found Friday Foil Open #80'},
#   '06/17/2017': {'base': 112,
#    'bonus': 8,
#    'event': "Senior Men's Foil",
#    'place': '6',
#    'rating': 'A4',
#    'size': '117',
#    'total': 120,
#    'tournament': 'NEUSFA , 2017 Pomme De Terre Individual'},
#   '08/25/2017': {'base': 24,
#    'bonus': 6,
#    'event': 'Senior Mixed Foil',
#    'place': '3',
#    'rating': 'NR',
#    'size': '26',
#    'total': 30,
#    'tournament': 'Moe Future Scholarship Foil Open'},
#   '08/28/2015': {'base': 28,
#    'bonus': 6,
#    'event': 'Mixed Foil',
#    'place': '3',
#    'rating': 'NR',
#    'size': '30',
#    'total': 34,
#    'tournament': 'Moe Found Friday Foil Open #81'},
#   '09/04/2015': {'base': 22,
#    'bonus': 10,
#    'event': 'Mixed Foil',
#    'place': '1',
#    'rating': 'NR',
#    'size': '22',
#    'total': 32,
#    'tournament': 'Moe Found Friday Foil Open #82'},
#   '09/12/2015': {'base': 90,
#    'bonus': 8,
#    'event': "Div1A Senior Men's Foil",
#    'place': '6',
#    'rating': 'A3',
#    'size': '95',
#    'total': 98,
#    'tournament': 'Thrust Fall ROC- Div 1A/Div 2 (Region 3)'},
#   '09/16/2016': {'base': 20,
#    'bonus': 4,
#    'event': 'Mixed Foil',
#    'place': '5',
#    'rating': 'NR',
#    'size': '24',
#    'total': 24,
#    'tournament': 'Moe Found Friday Foil Open #99'},
#   '10/21/2016': {'base': 29,
#    'bonus': 6,
#    'event': 'Mixed Foil',
#    'place': '3',
#    'rating': 'NR',
#    'size': '31',
#    'total': 35,
#    'tournament': 'Moe Found Friday Foil Open #100!'},
#   '10/23/2015': {'base': 20,
#    'bonus': 10,
#    'event': 'Mixed Foil',
#    'place': '1',
#    'rating': 'NR',
#    'size': '20',
#    'total': 30,
#    'tournament': 'Moe Found Friday Foil Open #83'},
#   '12/04/2015': {'base': 18,
#    'bonus': 6,
#    'event': 'Mixed Foil',
#    'place': '3',
#    'rating': 'NR',
#    'size': '20',
#    'total': 24,
#    'tournament': 'Moe Found Friday Foil Open #85'}},
#  'Moe 1': {'06/17/2017': {'base': 8,
#    'bonus': 8,
#    'event': "Senior Men's Team Foil",
#    'place': '1',
#    'rating': '">',
#    'size': '8',
#    'total': 16,
#    'tournament': 'NEUSFA 2017 Pomme De Terre - TEAM EVENTS'}},
#  'Moe FC': {'06/20/2015': {'base': 3,
#    'bonus': 2,
#    'event': "Senior Men's Team Foil",
#    'place': '6',
#    'rating': '">',
#    'size': '8',
#    'total': 5,
#    'tournament': 'NEUSFA , 2015 Pomme De Terre'}}}

# %%
board = []
for key in results_dict:
    total = 0
    
    for date in results_dict[key]:
        total += results_dict[key][date]['total']
    board.append((total, key))
board = sorted(board, reverse=True)
for entry in board:
    print(entry[0], entry[1])
#total
# Out:
# 350 Gruber, Samuel
# 250 Andrade, Nicholas
# 200 Cheng, Thomas
# 180 Sapienza, Stefano
# 179 Tsai, Philip
# 170 Molho, Sofia
# 167 Wong, Ethan
# 163 LaRosee, Matthew
# 131 Tsai, Max
# 124 Vo, Antoine
# 120 Sullivan, Jackson
# 111 Moo, Gareth
# 110 Baldini, Andrea
# 98 Tsai, Ryan
# 98 LeDonne, Renaud
# 84 Wong, Nathan
# 77 Nunley, Victoria
# 76 Jenkins, Hannah
# 73 Kelly, Katherine
# 68 Tecson, Michaela
# 63 McLean, Miles
# 61 Du, Hannah
# 60 Wilbert, Matthew
# 57 Litle, Elishua
# 56 Rea, Franklin T.
# 49 Banks, Alex
# 47 Yoon, Eugene
# 36 Tsai, Chia-Lun Jack
# 35 Jovanovic, Bojan
# 34 Domenicano, Ilaria
# 33 Wilbert, Gwendolyn
# 32 Wiest, Henry
# 30 Wencel, Clementine
# 30 Ma, Claire
# 30 Karamete, Irem
# 28 Zhou, Daniel
# 17 Miall, Steven
# 16 Moe 1
# 15 Romera, Julio
# 9 Gardiner, Sophia
# 8 Yang, Meler
# 7 Miao, Steven
# 7 Antoniv, Ivan
# 5 Morell, Alfonso
# 4 Wang, Zhao
# 4 Moe 1 Too
# 4 Kang, Daniel
# 2 Gardiner, Luke
# 2 Berger, Gregory
# 1 Tran, Arden

# %% [markdown]
# Tableau of 32
#
# Top 16 + 2
# Top 8 + 4
# Top 4 + 6
# Top 2 + 8
# Top 1 + 10

# %%
for key in results_dict:
    for weapon in results_dict[key]:
        for date in results_dict[key][weapon]:
            print(key,
                  weapon,
                  date, 
                  results_dict[key][weapon][date]['place'],
                  results_dict[key][weapon][date]['size'])
# Out:
# Du, Hannah foil 08/26/2017 24 36
# Du, Hannah foil 06/23/2017 16 24
# Gruber, Samuel foil 08/25/2017 2 26
# Gruber, Samuel foil 06/23/2017 3 24
# Gruber, Samuel foil 06/17/2017 15 117
# Litle, Elishua foil 08/25/2017 3 26
# Moo, Gareth foil 08/25/2017 7 26
# Moo, Gareth foil 06/23/2017 15 24
# Moo, Gareth foil 06/17/2017 73 117
# Nunley, Victoria foil 08/25/2017 9 26
# Nunley, Victoria foil 06/23/2017 8 24
# Nunley, Victoria foil 06/17/2017 23 56
# Zhou, Daniel foil 08/25/2017 12 26
# Yoon, Eugene foil 08/25/2017 16 26
# Yoon, Eugene foil 06/17/2017 41 59
# Wiest, Henry foil 08/25/2017 18 26
# Wiest, Henry foil 06/23/2017 17 24
# Wiest, Henry foil 06/17/2017 45 59
# Gardiner, Sophia foil 08/25/2017 22 26
# Gardiner, Sophia foil 06/23/2017 23 24
# Ma, Claire foil 08/25/2017 24 26
# Ma, Claire foil 06/23/2017 22 24
# Ma, Claire foil 06/17/2017 32 40
# Baldini, Andrea foil 08/25/2017 1 26
# Karamete, Irem foil 08/25/2017 3 26
# LaRosee, Matthew foil 08/25/2017 5 26
# LaRosee, Matthew foil 06/23/2017 5 24
# LaRosee, Matthew foil 06/17/2017 79 117
# Banks, Alex foil 08/25/2017 8 26
# Banks, Alex foil 06/17/2017 1 16
# Wilbert, Matthew foil 08/25/2017 10 26
# Wilbert, Matthew foil 06/17/2017 6 16
# Wilbert, Gwendolyn foil 08/25/2017 15 26
# Wilbert, Gwendolyn foil 06/17/2017 44 56
# Miall, Steven foil 08/25/2017 17 26
# Jenkins, Hannah foil 08/25/2017 21 26
# Jenkins, Hannah foil 06/23/2017 19 24
# Jenkins, Hannah foil 06/17/2017 2 40
# Kang, Daniel foil 08/25/2017 23 26
# Gardiner, Luke foil 08/25/2017 25 26
# Yang, Meler foil 08/25/2017 26 26
# Sapienza, Stefano foil 06/23/2017 2 24
# Sapienza, Stefano foil 06/17/2017 46 117
# Cheng, Thomas foil 06/23/2017 3 24
# Cheng, Thomas foil 06/17/2017 64 117
# LeDonne, Renaud foil 06/23/2017 6 24
# LeDonne, Renaud foil 06/17/2017 98 117
# Tsai, Philip foil 06/23/2017 10 24
# Tsai, Philip foil 06/17/2017 14 59
# Vo, Antoine foil 06/23/2017 12 24
# Vo, Antoine foil 06/17/2017 101 117
# Sullivan, Jackson foil 06/23/2017 14 24
# Sullivan, Jackson foil 06/17/2017 8 59
# Miao, Steven foil 06/23/2017 18 24
# Andrade, Nicholas foil 06/23/2017 1 24
# Andrade, Nicholas foil 06/17/2017 8 117
# Molho, Sofia foil 06/23/2017 7 24
# Molho, Sofia foil 06/17/2017 7 56
# Tsai, Ryan foil 06/23/2017 9 24
# Tsai, Ryan foil 06/17/2017 83 117
# Wong, Ethan foil 06/23/2017 11 24
# Wong, Ethan foil 06/17/2017 33 117
# Wong, Nathan foil 06/23/2017 13 24
# Wong, Nathan foil 06/17/2017 69 117
# Tsai, Max foil 06/23/2017 20 24
# Antoniv, Ivan saber 06/17/2017 54 60
# Wang, Zhao foil 06/23/2017 24 24
# Kelly, Katherine foil 06/17/2017 22 56
# Romera, Julio saber 06/17/2017 3 13
# Moe 1 Too foil 06/17/2017 7 8
# Tsai, Chia-Lun Jack foil 06/17/2017 25 59
# Tecson, Michaela foil 06/17/2017 8 40
# Domenicano, Ilaria saber 06/17/2017 19 50
# Moe 1 foil 06/17/2017 1 8
# Rea, Franklin T. saber 06/17/2017 9 60

# %%
results_dict['Wilbert, Matthew']['08/25/2017']['event']
# Out:
# 'Senior Mixed Foil'

# %%
membership = pd.read_csv('EOY-2017.csv')

# %%
membership.head(10)
# Out:
#    Last Name      First Name Middle Name Suffix Nickname Gender  Birthdate  \
# 0        NaN  Steven Glidden         NaN    NaN      NaN      M  1/01/2006
# 1    Simmons            John      Medard    NaN      NaN      M  1/01/2007
# 2   Szilagyi           Eamon         NaN    NaN      NaN      M    1/01/-1
# 3         Xu           Ethan         NaN    NaN      NaN      M  1/01/2008
# 4          '          Shevek         NaN    NaN      NaN      M  1/01/1979
# 5      Aamer            Zain         NaN    NaN      NaN      M  1/01/2000
# 6      Aaron        Nicholas           E    NaN      NaN      M  1/01/1998
# 7     Aarons            Aria         NaN    NaN      NaN      F  1/01/2004
# 8       Abad          Mischa         NaN    NaN      NaN      F  1/01/2007
# 9     Abadou             Ava         NaN    NaN      NaN      F  1/01/2010
#
#   Birthdate verified             Division  Section        ...          \
# 0                 No                  NaN      NaN        ...
# 1                Yes          New England      NaN        ...
# 2                 No          Connecticut      NaN        ...
# 3                 No          New England      NaN        ...
# 4                 No  Northern California      NaN        ...
# 5                 No             Illinois      NaN        ...
# 6                Yes               Oregon      NaN        ...
# 7                 No      Central Florida      NaN        ...
# 8                 No               Nevada      NaN        ...
# 9                 No  Northern California      NaN        ...
#
#   Expiration Saber  Epee Foil US Citizen  Permanent Resident  \
# 0  7/31/2018     U     U    U        Yes                  No
# 1  7/31/2017     U     U    U        Yes                  No
# 2  7/31/2018     U     U    U        Yes                  No
# 3  7/31/2018     U     U    U        Yes                  No
# 4  7/31/2017     U   D16    U         No                  No
# 5  7/31/2017     U     U    U        Yes                  No
# 6  7/31/2017   D16     U    U        Yes                  No
# 7  7/31/2017     U     U    U        Yes                  No
# 8  7/31/2017     U     U    U        Yes                  No
# 9  7/31/2017     U     U    U        Yes                  No
#
#        Representing Country  Region #  Background Check Expires  \
# 0  United States of America       NaN                       NaN
# 1  United States of America       3.0                       NaN
# 2  United States of America       3.0                       NaN
# 3  United States of America       3.0                       NaN
# 4             Great Britain       4.0                       NaN
# 5  United States of America       2.0                       NaN
# 6  United States of America       1.0                 2/25/2018
# 7  United States of America       6.0                       NaN
# 8  United States of America       4.0                       NaN
# 9  United States of America       4.0                       NaN
#
#    SafeSport Expires
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# 5                NaN
# 6                NaN
# 7                NaN
# 8                NaN
# 9                NaN
#
# [10 rows x 32 columns]

# %%
for fencer in results_dict:
    #print(fencer)
    if ',' in fencer:
        brk = str(fencer).index(',')
        last = fencer[:brk]
        first = fencer[brk+2:]
        if ' ' in first:
            brk = first.index(' ')
            first = first[:brk]
        tdf = membership[membership['Last Name'] == last]
        tdf = tdf[tdf['First Name'] == first]
#         results_dict[fencer]['mf'] = tdf['Gender']
#         results_dict[fencer]['birth_year'] = tdf['Birthdate']
        blank = []
#         blank.append(tdf.loc[0]['Gender'])
#         blank.append(tdf.loc[0]['Birthdate'])
        print(fencer, blank)
        #str(tdf['Gender']), str(tdf['Birthdate']))
        print( )
        print(last)
        print(first)
        print()
        
# for fencer in results_dict:
#     print(results_dict[fencer])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1433                 if not ax.contains(key):
# -> 1434                     error()
#    1435             except TypeError as e:
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#
# KeyError: 'the label [0] is not in the [index]'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-323-0dc3c69bc539> in <module>()
#      13 #         results_dict[fencer]['birth_year'] = tdf['Birthdate']
#      14         blank = []
# ---> 15         blank.append(tdf.loc[0]['Gender'])
#      16         blank.append(tdf.loc[0]['Birthdate'])
#      17         print(fencer, blank)
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in __getitem__(self, key)
#    1326         else:
#    1327             key = com._apply_if_callable(key, self.obj)
# -> 1328             return self._getitem_axis(key, axis=0)
#    1329
#    1330     def _is_scalar_access(self, key):
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _getitem_axis(self, key, axis)
#    1549
#    1550         # fall thru to straight lookup
# -> 1551         self._has_valid_type(key, axis)
#    1552         return self._get_label(key, axis=axis)
#    1553
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in _has_valid_type(self, key, axis)
#    1440                 raise
#    1441             except:
# -> 1442                 error()
#    1443
#    1444         return True
#
# /anaconda/lib/python3.6/site-packages/pandas/core/indexing.py in error()
#    1427                                     "key")
#    1428                 raise KeyError("the label [%s] is not in the [%s]" %
# -> 1429                                (key, self.obj._get_axis_name(axis)))
#    1430
#    1431             try:
#
# KeyError: 'the label [0] is not in the [index]'

# %%
membership[membership['Last Name']=='Molho']
# Out:
#       Last Name First Name Middle Name Suffix Nickname Gender  Birthdate  \
# 22847     Molho      Sofia         NaN    NaN      NaN      F  1/01/2002
#
#       Birthdate verified     Division  Section        ...         Expiration  \
# 22847                Yes  New England      NaN        ...          7/31/2018
#
#       Saber  Epee Foil US Citizen  Permanent Resident  \
# 22847     U     U  C17        Yes                  No
#
#            Representing Country  Region #  Background Check Expires  \
# 22847  United States of America       3.0                       NaN
#
#        SafeSport Expires
# 22847                NaN
#
# [1 rows x 32 columns]
